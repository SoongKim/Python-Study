# %%
import pandas as pd
import urllib.parse

# %%
MARKET_CODE_DICT = {

    'kospi': 'stockMkt',

    'kosdaq': 'kosdaqMkt',

    'konex': 'konexMkt'

}

DOWNLOAD_URL = 'https://kind.krx.co.kr/corpgeneral/corpList.do'

# %%
def zeroFill(columnValue):

    columnValue = str(columnValue)

    outValue = columnValue.zfill(6)

    return outValue

# %%
def get_stock_codes(market=None, delisted=False):

    params = {'method': 'download'}

    if market.lower() in MARKET_CODE_DICT:

        ## marketType 키 추가

        params['marketType'] = MARKET_CODE_DICT[market]

        print(market.lower()+" market key is exist")

    else:

        print("invalid market")

    # make url  key=value & key = value
    params_string = urllib.parse.urlencode(params)    

    request_url = DOWNLOAD_URL+"?"+params_string

    df = pd.read_html(request_url)[0]

    df["종목코드"] = df.종목코드.apply(zeroFill)
#     df["종목코드"] = df.종목코드.map('{:06d}'.format) # 동일 결과
#     06d : 숫자가 없는 칸은 0으로 맞춰줌.
 
    return df

# %%
stocks = get_stock_codes('kospi')

stocks
# Out:
# kospi market key is exist
#             회사명    종목코드               업종  \
# 0        AJ네트웍스  095570  산업용 기계 및 장비 임대업
# 1       BNK금융지주  138930           기타 금융업
# 2           DSR  155660      1차 비철금속 제조업
# 3            GS  078930           기타 금융업
# 4     HDC현대산업개발  294870           건물 건설업
# ..          ...     ...              ...
# 824     현대코퍼레이션  011760        상품 종합 도매업
# 825  현대코퍼레이션홀딩스  227840   음·식료품 및 담배 도매업
# 826          화신  010690    자동차 신품 부품 제조업
# 827      효성첨단소재  298050         화학섬유 제조업
# 828        흥아해운  003280           해상 운송업
#
#                                                 주요제품         상장일  결산월  \
# 0                                렌탈(파렛트, OA장비, 건설장비)  2015-08-21  12월
# 1                                             금융지주회사  2011-03-30  12월
# 2                                             합섬섬유로프  2013-05-15  12월
# 3                                        지주회사/부동산 임대  2004-08-05  12월
# 4                             외주주택, 자체공사, 일반건축, 토목 등  2018-06-12  12월
# ..                                               ...         ...  ...
# 824  자동차,철강,기계,선박,플랜트,컴퓨터,전자제품 수출,수출입대행/자원(탄광,유전) 개발  1977-12-01  12월
# 825                                      브랜드사업, 육류유통  2015-10-23  12월
# 826                    자동차엔진부품(ARM류,C/MBR류),자동차부품 제조  1994-01-14  12월
# 827                                         PET타이어코드  2018-07-13  12월
# 828                                   외항화물운송업(케미컬탱커)  1976-06-29  12월
#
#                         대표자명                                     홈페이지     지역
# 0                        손삼달                   http://www.ajnet.co.kr  서울특별시
# 1                        빈대인                     http://www.bnkfg.com  부산광역시
# 2                        홍석빈                       http://www.dsr.com  부산광역시
# 3         허태수, 홍순기 (각자 대표이사)                                      NaN  서울특별시
# 4    최익훈, 정익희, 김회언 (각자 대표이사)                   http://www.hdc-dvp.com  서울특별시
# ..                       ...                                      ...    ...
# 824    정몽혁, 김원갑, 장안석(각자대표이사)             http://www.hyundaicorp.co.kr  서울특별시
# 825         정몽혁, 김원갑(각자대표이사)       http://www.hyundaicorpholdings.com  서울특별시
# 826                 정서진, 장의호                 http://www.hwashin.co.kr   경상북도
# 827                      조용수  http://www.hyosungadvancedmaterials.com  서울특별시
# 828                      이환구                   http://www.heung-a.com  서울특별시
#
# [829 rows x 9 columns]

# %%
stock_code = stocks.iloc[0]['종목코드']
stock_name = stocks.iloc[0]['회사명']
print(stock_name)
print(stock_code)
# 내가 원하는 종목을 가져올 수 있다 ( 여기까지 했다면 )
# Out:
# AJ네트웍스
# 095570

# %%
stocks.dtypes
# Out:
# 회사명     object
# 종목코드    object
# 업종      object
# 주요제품    object
# 상장일     object
# 결산월     object
# 대표자명    object
# 홈페이지    object
# 지역      object
# dtype: object

# %%
seek1 = "보험업"
seek2 = "손해보험"

# %%
seekCom = stocks.loc[(stocks.업종.str.upper() == seek1) & (stocks.주요제품.str.upper() == seek2)]

# %%
seekCom
# Out:
#         회사명    종목코드   업종  주요제품         상장일  결산월 대표자명  \
# 215    흥국화재  000540  보험업  손해보험  1974-12-05  12월  임규준
# 610  한화손해보험  000370  보험업  손해보험  1975-06-30  12월  나채범
#
#                              홈페이지     지역
# 215    http://www.insurance.co.kr  서울특별시
# 610  http://www.hwgeneralins.com/  서울특별시

# %%
targetColumn = ["종목코드"]

# %%
seekStockCode = seekCom.loc[: ,targetColumn]

# %%
seekStockCode
# Out:
#        종목코드
# 215  000540
# 610  000370

# %%
import FinanceDataReader as web
from datetime import date, timedelta
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline
from matplotlib import font_manager, rc
import platform

print(platform.system())

if platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
elif platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
else:
    pass
# Out:
# Windows

# %%
end = date.today()
start = date.today() - timedelta(50) # datetime.datetime(2021,4,1) 

STOCK = web.DataReader(stock_code, start, end)
STOCK
# Out:
#             Open  High   Low  Close  Volume    Change
# Date
# 2023-04-03  4705  4750  4625   4650  191846 -0.012739
# 2023-04-04  4680  4800  4580   4735  163332  0.018280
# 2023-04-05  4685  4765  4635   4670  147912 -0.013728
# 2023-04-06  4685  4730  4590   4660  189535 -0.002141
# 2023-04-07  4715  4745  4615   4660  157004  0.000000
# 2023-04-10  4690  4690  4545   4590  171670 -0.015021
# 2023-04-11  4565  4670  4510   4660  125234  0.015251
# 2023-04-12  4630  4870  4620   4825  193919  0.035408
# 2023-04-13  4830  4875  4700   4860  146406  0.007254
# 2023-04-14  4865  4965  4780   4910  155165  0.010288
# 2023-04-17  4880  4925  4790   4895   96113 -0.003055
# 2023-04-18  4865  4950  4825   4940  105981  0.009193
# 2023-04-19  4980  5070  4940   4985  181013  0.009109
# 2023-04-20  4990  5010  4865   4870   72467 -0.023069
# 2023-04-21  4885  4935  4730   4880  103440  0.002053
# 2023-04-24  4930  4930  4740   4775  131038 -0.021516
# 2023-04-25  4800  4895  4615   4720  155396 -0.011518
# 2023-04-26  4685  4855  4615   4770  109051  0.010593
# 2023-04-27  4750  4810  4680   4750   64374 -0.004193
# 2023-04-28  4730  4750  4700   4720   45216 -0.006316
# 2023-05-02  4780  4780  4710   4750   30349  0.006356
# 2023-05-03  4690  4750  4680   4690   40512 -0.012632
# 2023-05-04  4700  4700  4625   4665   81427 -0.005330
# 2023-05-08  4665  4685  4640   4655   35188 -0.002144
# 2023-05-09  4655  4675  4605   4635   41192 -0.004296
# 2023-05-10  4635  4700  4620   4690   50520  0.011866
# 2023-05-11  4720  4830  4685   4720   67051  0.006397
# 2023-05-12  4700  4725  4595   4600   69655 -0.025424
# 2023-05-15  4600  4705  4555   4630   59647  0.006522
# 2023-05-16  4580  4625  4425   4460  211787 -0.036717
# 2023-05-17  4420  4505  4410   4475   51524  0.003363
# 2023-05-18  4460  4505  4410   4440   90904 -0.007821
# 2023-05-19  4470  4470  4425   4445   32448  0.001126
# 2023-05-22  4420  4490  4420   4450   46587  0.001125

# %%
STOCK['Close'].plot()
# print(plt.style.available)
# plt.style.use(['fivethirtyeight'])
plt.title(stock_name+" 종가 시세")
plt.show()

# %%
STOCK["MA_5"]=STOCK["Close"].rolling(window=5, min_periods=1).mean() # min_periods=1
STOCK["MA_20"]=STOCK["Close"].rolling(window=20, min_periods=1).mean()
STOCK["diff"]=STOCK["MA_5"]-STOCK["MA_20"]
STOCK.tail()
# Out:
#             Open  High   Low  Close  Volume    Change    MA_5   MA_20   diff
# Date
# 2023-05-16  4580  4625  4425   4460  211787 -0.036717  4620.0  4740.0 -120.0
# 2023-05-17  4420  4505  4410   4475   51524  0.003363  4577.0  4719.0 -142.0
# 2023-05-18  4460  4505  4410   4440   90904 -0.007821  4521.0  4694.0 -173.0
# 2023-05-19  4470  4470  4425   4445   32448  0.001126  4490.0  4667.0 -177.0
# 2023-05-22  4420  4490  4420   4450   46587  0.001125  4454.0  4646.0 -192.0

# %%
plt.figure(figsize = (16,10))

#price (가격)
plt.subplot(311)
plt.plot(STOCK.index, STOCK['Close'], label = 'Close')
plt.plot(STOCK.index, STOCK['MA_5'], label='MA 5day')
plt.plot(STOCK.index, STOCK['MA_20'], label='MA 20day')
plt.title(stock_name+"분석결과")
plt.legend(loc='best')

# volume (거래량)
plt.subplot(312)
plt.bar(STOCK.index, STOCK['Volume'], color='black')

#  이동평균 차이 (diff)
plt.subplot(313)
plt.rc('axes', unicode_minus=False)
plt.plot(STOCK.index, STOCK['diff'].fillna(0), color='g')
plt.axhline(y=0, color='r',linestyle=':', linewidth=3) # https://financedata.github.io/posts/matplotlib_hline_and_vline.html
