# %%
import pandas as pd

# %%
pd.read_csv("../../stdcode6/dataset/pipedata.txt")
# Out:
#    a|b|c
# 0  1|2|3
# 1  4|5|6

# %%
# 컬럼으로 구분해야 하는데, 얘는 파이프라인으로 구분해서 문제가 발생한다.

# %%
pd.read_csv("../../stdcode6/dataset/pipedata.txt", sep = "|")
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
# 구분자 : Seperator / Delimeter 라고 한다.
# 위 케이스의 경우, | 기준으로 데이터가 나눠져 있으니
# sep(=Seperator) = "|"를 사용하였다.

# %%
# 혹여나 45,34 처럼 콤마를 사용하는 데이터가 존재한다면
# 반드시 sep를 tab, 혹은 |와 같은 것을 별도로 지정해주어
# 필요한 데이터가 떨어지지 않도록 조치해주자.

# %%
indata = pd.read_csv("../../stdcode6/dataset/customer.csv")

# %%
indata.columns = ["BA", "ST", "LA"]

# %%
indata.to_csv("../../stdcode6/dataset/customer.csv", index = False)

# %%
indata
# Out:
#               BA        ST       LA
# 0       30000000  22500000   normal
# 1      280000000  48000000  diamond
# 2      300000000  40666666  diamond
# 3       54000000  28000000   normal
# 4      768000000  32000000      vip
# ...          ...       ...      ...
# 19995  628000000  44666666  diamond
# 19996  276000000  20000000   normal
# 19997  652000000  41333333  diamond
# 19998  676000000  45333333  diamond
# 19999  732000000  26000000  diamond
#
# [20000 rows x 3 columns]

# %%
# APZID, 데이터 표준화

# %%
import pandas as pd
import psycopg2

from sqlalchemy import create_engine

# %%
postEngine = create_engine("postgresql://postgres:postgres@127.0.0.1:5432/postgres")

# %%
inId = "kopo"
inPw = "kopo"
inIp = "139.150.80.154"
inPort = "5432"
inDbName = "kopo"

# %%
'postgresql://{}:{}@{}:{}/{}'.format(inId,inPw,inIp,inPort,inDbName)
# Out:
# 'postgresql://kopo:kopo@139.150.80.154:5432/kopo'

# %%
resultName = "pgresult_sk"

# %%
conDb = pd.read_sql_query("select * from pgresult_sk", con=postEngine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
# ...

# %%
pd.read_table("pgresult",con

# %%
indata.to_sql(name=resultName, con=postEngine, if_exists="replace", index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
# ...

# %%
indata = pd.read_csv("../../stdcode6/dataset/kopo_product_volume.csv")

# %%
indata
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK  VOLUME
# 0        A01       ST0001    201415  810144
# 1        A01       ST0002    201415  128999
# 2        A01       ST0001    201418  671464
# 3        A01       ST0002    201418  134467
# 4        A01       ST0001    201413  470040
# ..       ...          ...       ...     ...
# 260      A01       ST0002    201614  148835
# 261      A01       ST0001    201641  746061
# 262      A01       ST0002    201412  151750
# 263      A01       ST0001    201420  645626
# 264      A01       ST0002    201420  125863
#
# [265 rows x 4 columns]

# %%
indata.columns = indata.columns.str.lower()
# 문자열 함수를 사용한다.

# %%
indata
# Out:
#     regionid productgroup  yearweek  volume
# 0        A01       ST0001    201415  810144
# 1        A01       ST0002    201415  128999
# 2        A01       ST0001    201418  671464
# 3        A01       ST0002    201418  134467
# 4        A01       ST0001    201413  470040
# ..       ...          ...       ...     ...
# 260      A01       ST0002    201614  148835
# 261      A01       ST0001    201641  746061
# 262      A01       ST0002    201412  151750
# 263      A01       ST0001    201420  645626
# 264      A01       ST0002    201420  125863
#
# [265 rows x 4 columns]

# %%
import pandas as pd
import pymysql

# %%
from sqlalchemy import create_engine

# %%
# 금일 강의 진행 분량

# %%
# 1. selenium. 이메일 전송
# 셀레니움(웹페이지에 접근하게 해준다.)
# SMTP 라이브러리와 이메일 전송 자동화

# %%
# 2. 공공데이터 포털 수집
# 파일데이터 수집
# API(Json)
# API(Xml)

# %%
# 3. 데이터베이스 ETL
# Python 분석 역할
# 데이터 레이크와 데이터 웨어하우스의 개념
# 데이터 레이크 : 변형이 이뤄지지 않는 Raw Data
# 데이터 웨어하우스 : 목적에 맞춰 정형화시킨 데이터
# 파이썬 분석의 역할:
# 상이한 데이터 소스를 활용, 
# 해당 데이터에서 인사이트를 도출하여 필요한 곳에 전달한다.

# %%
# 데이터베이스, 파일, 웹 크롤링, 소스 등을
# 불러오는 방법을 이해해야 한다.

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %%
dbId = "system"
dbPw = "oracle"
dbIp = "192.168.110.25"
dbpt = "1521"
dbNM = "xe"
engine = create_engine('oracle+cx_oracle://{}:{}@{}:{}/{}'.format(dbId,dbPw,dbIp,dbpt,dbNM))

# %%
selloutData = pd.read_sql_query('select * from tabs', engine)

# %%
selloutData
# Out:
#                   table_name tablespace_name cluster_name iot_name status  \
# 0     LOGMNR_SESSION_EVOLVE$          SYSAUX         None     None  VALID
# 1             LOGMNR_GLOBAL$          SYSAUX         None     None  VALID
# 2     LOGMNR_GT_TAB_INCLUDE$            None         None     None  VALID
# 3    LOGMNR_GT_USER_INCLUDE$            None         None     None  VALID
# 4     LOGMNR_GT_XID_INCLUDE$            None         None     None  VALID
# ..                       ...             ...          ...      ...    ...
# 149      LOGSTDBY$EDS_TABLES          SYSAUX         None     None  VALID
# 150              DEF$_AQCALL          SYSTEM         None     None  VALID
# 151             DEF$_AQERROR          SYSTEM         None     None  VALID
# 152  SQLPLUS_PRODUCT_PROFILE          SYSTEM         None     None  VALID
# 153                     HELP          SYSTEM         None     None  VALID
#
#      pct_free  pct_used  ini_trans  max_trans  initial_extent  ...  \
# ...

# %%
sellOutData.columns
